# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    #print(x.shape)
    x = (x-np.min(x))/(np.max(x)-np.min(x))
    # TODO: Implement Function
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    nb_classes = 10
    #print(x)
    targets = np.array(x).reshape(-1)
    #print(targets)
    one_hot_targets = np.eye(nb_classes)[targets]
    return one_hot_targets


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    #print(image_shape)
    # TODO: Implement Function    
    x = tf.placeholder(tf.float32,(None,image_shape[0],image_shape[1],image_shape[2]),name="x")
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.int32,(None,n_classes),name="y")
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32,name="keep_prob")
    #print(keep_prob.get_shape().ndims)
    #assert nn_inputs_out_k.get_shape().ndims is None
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    
    print('conv2d_maxpool',x_tensor.shape)
    #print(x_tensor.shape[3])
    
    # convert into list and get the third element for the depth of the input element tensor
    depth = x_tensor.shape.as_list()[3]
    
    # TODO: Implement Function
    
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],depth,conv_num_outputs],stddev=0.05),name="weights")
    bias = tf.Variable(tf.zeros(conv_num_outputs),name="bias")
    
    conv_layer = tf.nn.conv2d(x_tensor,weights,strides=[1,conv_strides[0],conv_strides[1],1],padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer,bias)        
    conv_layer = tf.nn.relu(conv_layer)
    conv_layer = tf.nn.max_pool(
                            conv_layer,
                            ksize=[1,pool_ksize[0],pool_ksize[1],1],
                            strides=[1,pool_strides[0],pool_strides[1],1],
                            padding='SAME')
    
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# conv2d_maxpool (?, 32, 32, 5)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    #print(x_tensor.shape)
    print('flatten',x_tensor.shape)
    flatten_image_shape = x_tensor.get_shape().as_list()[1] * x_tensor.get_shape().as_list()[2] * x_tensor.get_shape().as_list()[3]
    #print(flatten_image_shape)
    reshaped_ts = tf.reshape(x_tensor,[-1,flatten_image_shape ])
    #print(reshaped_ts)
    return reshaped_ts


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# flatten (?, 10, 30, 6)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print('fully_conn',x_tensor.shape)
    flatten_input_nodes_perimage = x_tensor.get_shape().as_list()[1]
    #print(flatten_input_nodes_perimage)
    #print(num_outputs)
    fc_weights = tf.Variable(tf.truncated_normal(shape=(flatten_input_nodes_perimage,num_outputs),stddev=0.05))
    fc_bias = tf.Variable(tf.zeros(num_outputs))
    fc_layer = tf.add(tf.matmul(x_tensor,fc_weights),fc_bias)
    fc_layer = tf.nn.relu(fc_layer)
    return fc_layer
    #return tf.contrib.layers.fully_connected(x_tensor,num_outputs,activation_fn=tf.nn.relu)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# fully_conn (?, 128)
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    print('output layer',x_tensor.shape)
    op_weights = tf.Variable(tf.truncated_normal(shape=(x_tensor.get_shape().as_list()[1],num_outputs),stddev=0.05))
    op_bias = tf.Variable(tf.zeros(num_outputs))
    op_layer = tf.add(tf.matmul(x_tensor,op_weights),op_bias)
    return op_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# output layer (?, 128)
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #print(x.shape)
    conv_num_outputs = 32
    conv_ksize = (3,3)
    conv_strides = (1,1)
    pool_ksize = (2,2)
    pool_strides = (2,2)
    
    
    
    layer1_conv2d = conv2d_maxpool(x,
                   conv_num_outputs=conv_num_outputs,
                   conv_ksize=conv_ksize,
                   conv_strides=conv_strides,
                   pool_ksize=pool_ksize,
                   pool_strides = pool_strides)
    
    #layer1_1_dropout = tf.nn.dropout(layer1_conv2d,keep_prob=keep_prob)
    
    #conv_num_outputs = 100
    
    layer2_conv2d = conv2d_maxpool(layer1_conv2d,
                   conv_num_outputs=128,
                   conv_ksize=conv_ksize,
                   conv_strides=conv_strides,
                   pool_ksize=pool_ksize,
                   pool_strides = pool_strides)
    
    #layer2_1_dropout = tf.nn.dropout(layer2_conv2d,keep_prob=keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    layer3_flatten = flatten(layer2_conv2d)    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    #conv_num_outputs = 25
    layer4_fc = fully_conn(layer3_flatten,num_outputs=128)
    #conv_num_outputs = 15
    layer5_fc = fully_conn(layer4_fc,num_outputs=64)
    
    layer5_1_dropout = tf.nn.dropout(layer5_fc,keep_prob=keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    #conv_num_outputs = 10
    layer6_op = output(layer5_1_dropout,num_outputs=10)
    print('output layer output',layer6_op.shape)
    # TODO: return output
    return layer6_op


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# conv2d_maxpool (?, 32, 32, 3)
# conv2d_maxpool (?, 16, 16, 32)
# flatten (?, 8, 8, 128)
# fully_conn (?, 8192)
# fully_conn (?, 128)
# output layer (?, 64)
# output layer output (?, 10)
# conv2d_maxpool (?, 32, 32, 3)
# conv2d_maxpool (?, 16, 16, 32)
# flatten (?, 8, 8, 128)
# fully_conn (?, 8192)
# fully_conn (?, 128)
# output layer (?, 64)
# output layer output (?, 10)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    # Model
    # print('inside train_neural_network',feature_batch.shape)
    #logits = conv_net(x, weights, biases, keep_prob)
    session.run(optimizer,feed_dict={
            x : feature_batch,
            y : label_batch,
            keep_prob : keep_probability
        })
    #pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost,feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: 1.0
        })
    accuracy = session.run(accuracy, feed_dict={
            x: valid_features,
            y: valid_labels,
            keep_prob: 1.0
        })
    print('Loss: ', loss)
    print('Accuracy', accuracy)
    #pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5
print(batch_size)
# Out:
# 256

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
print(batch_size)
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# 256
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:  2.1848
# Accuracy 0.2666
# Epoch  2, CIFAR-10 Batch 1:  Loss:  2.03337
# Accuracy 0.3556
# Epoch  3, CIFAR-10 Batch 1:  Loss:  1.95607
# Accuracy 0.368
# Epoch  4, CIFAR-10 Batch 1:  Loss:  1.82069
# Accuracy 0.4012
# Epoch  5, CIFAR-10 Batch 1:  Loss:  1.67104
# Accuracy 0.4256
# Epoch  6, CIFAR-10 Batch 1:  Loss:  1.5746
# Accuracy 0.4294
# Epoch  7, CIFAR-10 Batch 1:  Loss:  1.52155
# Accuracy 0.4636
# Epoch  8, CIFAR-10 Batch 1:  Loss:  1.32663
# Accuracy 0.4736
# Epoch  9, CIFAR-10 Batch 1:  Loss:  1.21923
# Accuracy 0.4886
# Epoch 10, CIFAR-10 Batch 1:  Loss:  1.15705
# Accuracy 0.497
# Epoch 11, CIFAR-10 Batch 1:  Loss:  1.05726
# Accuracy 0.5004
# Epoch 12, CIFAR-10 Batch 1:  Loss:  0.982519
# Accuracy 0.5062
# Epoch 13, CIFAR-10 Batch 1:  Loss:  0.914208
# Accuracy 0.5138
# Epoch 14, CIFAR-10 Batch 1:  Loss:  0.853748
# Accuracy 0.5246
# Epoch 15, CIFAR-10 Batch 1:  Loss:  0.766989
# Accuracy 0.533
# Epoch 16, CIFAR-10 Batch 1:  Loss:  0.708861
# Accuracy 0.5446
# Epoch 17, CIFAR-10 Batch 1:  Loss:  0.70266
# Accuracy 0.5434
# Epoch 18, CIFAR-10 Batch 1:  Loss:  0.641038
# Accuracy 0.5482
# Epoch 19, CIFAR-10 Batch 1:  Loss:  0.545085
# Accuracy 0.559
# Epoch 20, CIFAR-10 Batch 1:  Loss:  0.489573
# Accuracy 0.5684
# Epoch 21, CIFAR-10 Batch 1:  Loss:  0.477737
# Accuracy 0.565
# Epoch 22, CIFAR-10 Batch 1:  Loss:  0.407483
# Accuracy 0.572
# Epoch 23, CIFAR-10 Batch 1:  Loss:  0.368221
# Accuracy 0.5716
# Epoch 24, CIFAR-10 Batch 1:  Loss:  0.368878
# Accuracy 0.5554
# Epoch 25, CIFAR-10 Batch 1:  Loss:  0.266649
# Accuracy 0.5802
# Epoch 26, CIFAR-10 Batch 1:  Loss:  0.253549
# Accuracy 0.5894
# Epoch 27, CIFAR-10 Batch 1:  Loss:  0.290904
# Accuracy 0.5372
# Epoch 28, CIFAR-10 Batch 1:  Loss:  0.192623
# Accuracy 0.5904
# Epoch 29, CIFAR-10 Batch 1:  Loss:  0.151967
# Accuracy 0.6004
# Epoch 30, CIFAR-10 Batch 1:  Loss:  0.142372
# Accuracy 0.579
# Epoch 31, CIFAR-10 Batch 1:  Loss:  0.165351
# Accuracy 0.5984
# Epoch 32, CIFAR-10 Batch 1:  Loss:  0.123706
# Accuracy 0.6062
# Epoch 33, CIFAR-10 Batch 1:  Loss:  0.113795
# Accuracy 0.5976
# Epoch 34, CIFAR-10 Batch 1:  Loss:  0.148069
# Accuracy 0.5664
# Epoch 35, CIFAR-10 Batch 1:  Loss:  0.128954
# Accuracy 0.5464
# Epoch 36, CIFAR-10 Batch 1:  Loss:  0.0954729
# Accuracy 0.5878
# Epoch 37, CIFAR-10 Batch 1:  Loss:  0.107633
# Accuracy 0.557
# Epoch 38, CIFAR-10 Batch 1:  Loss:  0.0718185
# Accuracy 0.5646
# Epoch 39, CIFAR-10 Batch 1:  Loss:  0.0516291
# Accuracy 0.5974
# Epoch 40, CIFAR-10 Batch 1:  Loss:  0.0430665
# Accuracy 0.6026
# Epoch 41, CIFAR-10 Batch 1:  Loss:  0.0446631
# Accuracy 0.5922
# Epoch 42, CIFAR-10 Batch 1:  Loss:  0.030491
# Accuracy 0.602
# Epoch 43, CIFAR-10 Batch 1:  Loss:  0.0304557
# Accuracy 0.5918
# Epoch 44, CIFAR-10 Batch 1:  Loss:  0.0221699
# Accuracy 0.5872
# Epoch 45, CIFAR-10 Batch 1:  Loss:  0.0264028
# Accuracy 0.5692
# Epoch 46, CIFAR-10 Batch 1:  Loss:  0.0236151
# Accuracy 0.5726
# Epoch 47, CIFAR-10 Batch 1:  Loss:  0.0193038
# Accuracy 0.575
# Epoch 48, CIFAR-10 Batch 1:  Loss:  0.0424063
# Accuracy 0.5684
# Epoch 49, CIFAR-10 Batch 1:  Loss:  0.0212392
# Accuracy 0.5704
# Epoch 50, CIFAR-10 Batch 1:  Loss:  0.0219008
# Accuracy 0.5712
# Epoch 51, CIFAR-10 Batch 1:  Loss:  0.0163615
# Accuracy 0.5778
# Epoch 52, CIFAR-10 Batch 1:  Loss:  0.0386323
# Accuracy 0.5462
# Epoch 53, CIFAR-10 Batch 1:  Loss:  0.0244851
# Accuracy 0.5588
# Epoch 54, CIFAR-10 Batch 1:  Loss:  0.0113622
# Accuracy 0.5794
# Epoch 55, CIFAR-10 Batch 1:  Loss:  0.00753594
# Accuracy 0.5946
# Epoch 56, CIFAR-10 Batch 1:  Loss:  0.00328797
# Accuracy 0.5956
# Epoch 57, CIFAR-10 Batch 1:  Loss:  0.00188381
# Accuracy 0.5842
# Epoch 58, CIFAR-10 Batch 1:  Loss:  0.00196333
# Accuracy 0.5914
# Epoch 59, CIFAR-10 Batch 1:  Loss:  0.0017244
# Accuracy 0.5728
# Epoch 60, CIFAR-10 Batch 1:  Loss:  0.00353201
# Accuracy 0.5592
# Epoch 61, CIFAR-10 Batch 1:  Loss:  0.00364978
# Accuracy 0.5682
# Epoch 62, CIFAR-10 Batch 1:  Loss:  0.00356981
# Accuracy 0.5806
# Epoch 63, CIFAR-10 Batch 1:  Loss:  0.00223356
# Accuracy 0.5788
# Epoch 64, CIFAR-10 Batch 1:  Loss:  0.0046742
# Accuracy 0.571
# Epoch 65, CIFAR-10 Batch 1:  Loss:  0.000970264
# Accuracy 0.5872
# Epoch 66, CIFAR-10 Batch 1:  Loss:  0.00208066
# Accuracy 0.5788
# Epoch 67, CIFAR-10 Batch 1:  Loss:  0.00121765
# Accuracy 0.5878
# Epoch 68, CIFAR-10 Batch 1:  Loss:  0.00279689
# Accuracy 0.5778
# Epoch 69, CIFAR-10 Batch 1:  Loss:  0.00167675
# Accuracy 0.5772
# Epoch 70, CIFAR-10 Batch 1:  Loss:  0.00091544
# Accuracy 0.5866
# Epoch 71, CIFAR-10 Batch 1:  Loss:  0.00078213
# Accuracy 0.5862
# Epoch 72, CIFAR-10 Batch 1:  Loss:  0.000528311
# Accuracy 0.5938
# Epoch 73, CIFAR-10 Batch 1:  Loss:  0.00164117
# Accuracy 0.594
# Epoch 74, CIFAR-10 Batch 1:  Loss:  0.000417261
# Accuracy 0.5862
# Epoch 75, CIFAR-10 Batch 1:  Loss:  0.000512706
# Accuracy 0.5932
# Epoch 76, CIFAR-10 Batch 1:  Loss:  0.00035404
# Accuracy 0.592
# Epoch 77, CIFAR-10 Batch 1:  Loss:  0.000582618
# Accuracy 0.5868
# Epoch 78, CIFAR-10 Batch 1:  Loss:  0.000371654
# Accuracy 0.5922
# Epoch 79, CIFAR-10 Batch 1:  Loss:  0.000597802
# Accuracy 0.5844
# Epoch 80, CIFAR-10 Batch 1:  Loss:  0.000322675
# Accuracy 0.595
# Epoch 81, CIFAR-10 Batch 1:  Loss:  0.000181763
# Accuracy 0.6002
# Epoch 82, CIFAR-10 Batch 1:  Loss:  0.000675684
# Accuracy 0.5904
# Epoch 83, CIFAR-10 Batch 1:  Loss:  0.000568325
# Accuracy 0.5938
# Epoch 84, CIFAR-10 Batch 1:  Loss:  0.000275508
# Accuracy 0.5902
# Epoch 85, CIFAR-10 Batch 1:  Loss:  0.000657291
# Accuracy 0.5774
# Epoch 86, CIFAR-10 Batch 1:  Loss:  0.000118118
# Accuracy 0.5924
# Epoch 87, CIFAR-10 Batch 1:  Loss:  0.00105163
# Accuracy 0.5876
# Epoch 88, CIFAR-10 Batch 1:  Loss:  0.000311317
# Accuracy 0.579
# Epoch 89, CIFAR-10 Batch 1:  Loss:  9.97935e-05
# Accuracy 0.584
# Epoch 90, CIFAR-10 Batch 1:  Loss:  0.000109172
# Accuracy 0.577
# Epoch 91, CIFAR-10 Batch 1:  Loss:  0.000115454
# Accuracy 0.5904
# Epoch 92, CIFAR-10 Batch 1:  Loss:  8.03851e-05
# Accuracy 0.5924
# Epoch 93, CIFAR-10 Batch 1:  Loss:  8.1329e-05
# Accuracy 0.5858
# Epoch 94, CIFAR-10 Batch 1:  Loss:  0.000150862
# Accuracy 0.585
# Epoch 95, CIFAR-10 Batch 1:  Loss:  0.00016135
# Accuracy 0.5802
# Epoch 96, CIFAR-10 Batch 1:  Loss:  0.000958781
# Accuracy 0.5704
# Epoch 97, CIFAR-10 Batch 1:  Loss:  0.000114684
# Accuracy 0.5874
# Epoch 98, CIFAR-10 Batch 1:  Loss:  0.000253544
# Accuracy 0.578
# Epoch 99, CIFAR-10 Batch 1:  Loss:  0.000200796
# Accuracy 0.589
# Epoch 100, CIFAR-10 Batch 1:  Loss:  6.59064e-05
# Accuracy 0.5906

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:  2.17669
# Accuracy 0.2312
# Epoch  1, CIFAR-10 Batch 2:  Loss:  1.811
# Accuracy 0.349
# Epoch  1, CIFAR-10 Batch 3:  Loss:  1.57751
# Accuracy 0.383
# Epoch  1, CIFAR-10 Batch 4:  Loss:  1.6581
# Accuracy 0.4148
# Epoch  1, CIFAR-10 Batch 5:  Loss:  1.59145
# Accuracy 0.4282
# Epoch  2, CIFAR-10 Batch 1:  Loss:  1.76856
# Accuracy 0.4494
# Epoch  2, CIFAR-10 Batch 2:  Loss:  1.42365
# Accuracy 0.476
# Epoch  2, CIFAR-10 Batch 3:  Loss:  1.23598
# Accuracy 0.471
# Epoch  2, CIFAR-10 Batch 4:  Loss:  1.41298
# Accuracy 0.5182
# Epoch  2, CIFAR-10 Batch 5:  Loss:  1.31636
# Accuracy 0.5006
# Epoch  3, CIFAR-10 Batch 1:  Loss:  1.49
# Accuracy 0.508
# Epoch  3, CIFAR-10 Batch 2:  Loss:  1.12166
# Accuracy 0.5218
# Epoch  3, CIFAR-10 Batch 3:  Loss:  0.996837
# Accuracy 0.5214
# Epoch  3, CIFAR-10 Batch 4:  Loss:  1.23008
# Accuracy 0.55
# Epoch  3, CIFAR-10 Batch 5:  Loss:  1.09902
# Accuracy 0.5562
# Epoch  4, CIFAR-10 Batch 1:  Loss:  1.23767
# Accuracy 0.5588
# Epoch  4, CIFAR-10 Batch 2:  Loss:  0.955569
# Accuracy 0.574
# Epoch  4, CIFAR-10 Batch 3:  Loss:  0.884675
# Accuracy 0.5544
# Epoch  4, CIFAR-10 Batch 4:  Loss:  1.05596
# Accuracy 0.5812
# Epoch  4, CIFAR-10 Batch 5:  Loss:  0.941564
# Accuracy 0.58
# Epoch  5, CIFAR-10 Batch 1:  Loss:  1.04916
# Accuracy 0.5778
# Epoch  5, CIFAR-10 Batch 2:  Loss:  0.835117
# Accuracy 0.5892
# Epoch  5, CIFAR-10 Batch 3:  Loss:  0.710477
# Accuracy 0.5924
# Epoch  5, CIFAR-10 Batch 4:  Loss:  0.935659
# Accuracy 0.5996
# Epoch  5, CIFAR-10 Batch 5:  Loss:  0.846815
# Accuracy 0.6146
# Epoch  6, CIFAR-10 Batch 1:  Loss:  0.885768
# Accuracy 0.6108
# Epoch  6, CIFAR-10 Batch 2:  Loss:  0.697845
# Accuracy 0.6092
# Epoch  6, CIFAR-10 Batch 3:  Loss:  0.614564
# Accuracy 0.6194
# Epoch  6, CIFAR-10 Batch 4:  Loss:  0.830506
# Accuracy 0.6082
# Epoch  6, CIFAR-10 Batch 5:  Loss:  0.724854
# Accuracy 0.629
# Epoch  7, CIFAR-10 Batch 1:  Loss:  0.746988
# Accuracy 0.6216
# Epoch  7, CIFAR-10 Batch 2:  Loss:  0.57363
# Accuracy 0.6358
# Epoch  7, CIFAR-10 Batch 3:  Loss:  0.520186
# Accuracy 0.614
# Epoch  7, CIFAR-10 Batch 4:  Loss:  0.665739
# Accuracy 0.6352
# Epoch  7, CIFAR-10 Batch 5:  Loss:  0.57825
# Accuracy 0.6538
# Epoch  8, CIFAR-10 Batch 1:  Loss:  0.60235
# Accuracy 0.6328
# Epoch  8, CIFAR-10 Batch 2:  Loss:  0.483411
# Accuracy 0.6584
# Epoch  8, CIFAR-10 Batch 3:  Loss:  0.392364
# Accuracy 0.6456
# Epoch  8, CIFAR-10 Batch 4:  Loss:  0.573902
# Accuracy 0.649
# Epoch  8, CIFAR-10 Batch 5:  Loss:  0.479806
# Accuracy 0.6678
# Epoch  9, CIFAR-10 Batch 1:  Loss:  0.515585
# Accuracy 0.655
# Epoch  9, CIFAR-10 Batch 2:  Loss:  0.385414
# Accuracy 0.6728
# Epoch  9, CIFAR-10 Batch 3:  Loss:  0.309969
# Accuracy 0.6606
# Epoch  9, CIFAR-10 Batch 4:  Loss:  0.451692
# Accuracy 0.6558
# Epoch  9, CIFAR-10 Batch 5:  Loss:  0.387379
# Accuracy 0.674
# Epoch 10, CIFAR-10 Batch 1:  Loss:  0.428798
# Accuracy 0.6716
# Epoch 10, CIFAR-10 Batch 2:  Loss:  0.325999
# Accuracy 0.673
# Epoch 10, CIFAR-10 Batch 3:  Loss:  0.291077
# Accuracy 0.661
# Epoch 10, CIFAR-10 Batch 4:  Loss:  0.388533
# Accuracy 0.672
# Epoch 10, CIFAR-10 Batch 5:  Loss:  0.306001
# Accuracy 0.6814
# Epoch 11, CIFAR-10 Batch 1:  Loss:  0.357514
# Accuracy 0.6742
# Epoch 11, CIFAR-10 Batch 2:  Loss:  0.276277
# Accuracy 0.656
# Epoch 11, CIFAR-10 Batch 3:  Loss:  0.263369
# Accuracy 0.6612
# Epoch 11, CIFAR-10 Batch 4:  Loss:  0.331096
# Accuracy 0.6754
# Epoch 11, CIFAR-10 Batch 5:  Loss:  0.296702
# Accuracy 0.6698
# Epoch 12, CIFAR-10 Batch 1:  Loss:  0.293755
# Accuracy 0.6854
# Epoch 12, CIFAR-10 Batch 2:  Loss:  0.269332
# Accuracy 0.6598
# Epoch 12, CIFAR-10 Batch 3:  Loss:  0.212476
# Accuracy 0.682
# Epoch 12, CIFAR-10 Batch 4:  Loss:  0.287235
# Accuracy 0.688
# Epoch 12, CIFAR-10 Batch 5:  Loss:  0.204807
# Accuracy 0.687
# Epoch 13, CIFAR-10 Batch 1:  Loss:  0.243125
# Accuracy 0.6824
# Epoch 13, CIFAR-10 Batch 2:  Loss:  0.237887
# Accuracy 0.6994
# Epoch 13, CIFAR-10 Batch 3:  Loss:  0.173784
# Accuracy 0.679
# Epoch 13, CIFAR-10 Batch 4:  Loss:  0.256754
# Accuracy 0.6914
# Epoch 13, CIFAR-10 Batch 5:  Loss:  0.189274
# Accuracy 0.6792
# Epoch 14, CIFAR-10 Batch 1:  Loss:  0.197754
# Accuracy 0.6758
# Epoch 14, CIFAR-10 Batch 2:  Loss:  0.211429
# Accuracy 0.6944
# Epoch 14, CIFAR-10 Batch 3:  Loss:  0.144547
# Accuracy 0.6892
# Epoch 14, CIFAR-10 Batch 4:  Loss:  0.226857
# Accuracy 0.696
# Epoch 14, CIFAR-10 Batch 5:  Loss:  0.147687
# Accuracy 0.6976
# Epoch 15, CIFAR-10 Batch 1:  Loss:  0.166473
# Accuracy 0.6688
# Epoch 15, CIFAR-10 Batch 2:  Loss:  0.17388
# Accuracy 0.6932
# Epoch 15, CIFAR-10 Batch 3:  Loss:  0.131021
# Accuracy 0.694
# Epoch 15, CIFAR-10 Batch 4:  Loss:  0.155481
# Accuracy 0.6958
# Epoch 15, CIFAR-10 Batch 5:  Loss:  0.124233
# Accuracy 0.6912
# Epoch 16, CIFAR-10 Batch 1:  Loss:  0.174874
# Accuracy 0.669
# Epoch 16, CIFAR-10 Batch 2:  Loss:  0.195488
# Accuracy 0.6702
# Epoch 16, CIFAR-10 Batch 3:  Loss:  0.131192
# Accuracy 0.7012
# Epoch 16, CIFAR-10 Batch 4:  Loss:  0.133731
# Accuracy 0.7012
# Epoch 16, CIFAR-10 Batch 5:  Loss:  0.124538
# Accuracy 0.6672
# Epoch 17, CIFAR-10 Batch 1:  Loss:  0.175523
# Accuracy 0.676
# Epoch 17, CIFAR-10 Batch 2:  Loss:  0.110577
# Accuracy 0.6724
# Epoch 17, CIFAR-10 Batch 3:  Loss:  0.0964003
# Accuracy 0.707
# Epoch 17, CIFAR-10 Batch 4:  Loss:  0.109449
# Accuracy 0.7
# Epoch 17, CIFAR-10 Batch 5:  Loss:  0.0837406
# Accuracy 0.6812
# Epoch 18, CIFAR-10 Batch 1:  Loss:  0.184757
# Accuracy 0.6742
# Epoch 18, CIFAR-10 Batch 2:  Loss:  0.107532
# Accuracy 0.6824
# Epoch 18, CIFAR-10 Batch 3:  Loss:  0.0785687
# Accuracy 0.6962
# Epoch 18, CIFAR-10 Batch 4:  Loss:  0.0973875
# Accuracy 0.6864
# Epoch 18, CIFAR-10 Batch 5:  Loss:  0.0811336
# Accuracy 0.6848
# Epoch 19, CIFAR-10 Batch 1:  Loss:  0.115876
# Accuracy 0.681
# Epoch 19, CIFAR-10 Batch 2:  Loss:  0.0706867
# Accuracy 0.6844
# Epoch 19, CIFAR-10 Batch 3:  Loss:  0.0772517
# Accuracy 0.6972
# Epoch 19, CIFAR-10 Batch 4:  Loss:  0.0829097
# Accuracy 0.678
# Epoch 19, CIFAR-10 Batch 5:  Loss:  0.0558238
# Accuracy 0.671
# Epoch 20, CIFAR-10 Batch 1:  Loss:  0.083785
# Accuracy 0.6772
# Epoch 20, CIFAR-10 Batch 2:  Loss:  0.0660537
# Accuracy 0.6792
# Epoch 20, CIFAR-10 Batch 3:  Loss:  0.0710802
# Accuracy 0.6988
# Epoch 20, CIFAR-10 Batch 4:  Loss:  0.136406
# Accuracy 0.6446
# Epoch 20, CIFAR-10 Batch 5:  Loss:  0.0676018
# Accuracy 0.6762
# Epoch 21, CIFAR-10 Batch 1:  Loss:  0.0738668
# Accuracy 0.6906
# Epoch 21, CIFAR-10 Batch 2:  Loss:  0.0557498
# Accuracy 0.6792
# Epoch 21, CIFAR-10 Batch 3:  Loss:  0.053702
# Accuracy 0.7082
# Epoch 21, CIFAR-10 Batch 4:  Loss:  0.101163
# Accuracy 0.6398
# Epoch 21, CIFAR-10 Batch 5:  Loss:  0.0473834
# Accuracy 0.6764
# Epoch 22, CIFAR-10 Batch 1:  Loss:  0.0512913
# Accuracy 0.6906
# Epoch 22, CIFAR-10 Batch 2:  Loss:  0.0483794
# Accuracy 0.6792
# Epoch 22, CIFAR-10 Batch 3:  Loss:  0.0528734
# Accuracy 0.6934
# Epoch 22, CIFAR-10 Batch 4:  Loss:  0.0613533
# Accuracy 0.6488
# Epoch 22, CIFAR-10 Batch 5:  Loss:  0.0347672
# Accuracy 0.6826
# Epoch 23, CIFAR-10 Batch 1:  Loss:  0.0392459
# Accuracy 0.6894
# Epoch 23, CIFAR-10 Batch 2:  Loss:  0.0470319
# Accuracy 0.6896
# Epoch 23, CIFAR-10 Batch 3:  Loss:  0.0576426
# Accuracy 0.6914
# Epoch 23, CIFAR-10 Batch 4:  Loss:  0.0325047
# Accuracy 0.6796
# Epoch 23, CIFAR-10 Batch 5:  Loss:  0.0215056
# Accuracy 0.6942
# Epoch 24, CIFAR-10 Batch 1:  Loss:  0.0415843
# Accuracy 0.689
# Epoch 24, CIFAR-10 Batch 2:  Loss:  0.0267208
# Accuracy 0.6874
# Epoch 24, CIFAR-10 Batch 3:  Loss:  0.0443813
# Accuracy 0.6878
# Epoch 24, CIFAR-10 Batch 4:  Loss:  0.0232583
# Accuracy 0.6882
# Epoch 24, CIFAR-10 Batch 5:  Loss:  0.0236734
# Accuracy 0.6846
# Epoch 25, CIFAR-10 Batch 1:  Loss:  0.0426858
# Accuracy 0.6766
# Epoch 25, CIFAR-10 Batch 2:  Loss:  0.0212623
# Accuracy 0.6974
# Epoch 25, CIFAR-10 Batch 3:  Loss:  0.031372
# Accuracy 0.6876
# Epoch 25, CIFAR-10 Batch 4:  Loss:  0.030408
# Accuracy 0.6756
# Epoch 25, CIFAR-10 Batch 5:  Loss:  0.0171653
# Accuracy 0.6782
# Epoch 26, CIFAR-10 Batch 1:  Loss:  0.0255369
# Accuracy 0.681
# Epoch 26, CIFAR-10 Batch 2:  Loss:  0.0241483
# Accuracy 0.6902
# Epoch 26, CIFAR-10 Batch 3:  Loss:  0.0381094
# Accuracy 0.6794
# Epoch 26, CIFAR-10 Batch 4:  Loss:  0.0295704
# Accuracy 0.6872
# Epoch 26, CIFAR-10 Batch 5:  Loss:  0.0207906
# Accuracy 0.6786
# Epoch 27, CIFAR-10 Batch 1:  Loss:  0.0226531
# Accuracy 0.6678
# Epoch 27, CIFAR-10 Batch 2:  Loss:  0.0201615
# Accuracy 0.6932
# Epoch 27, CIFAR-10 Batch 3:  Loss:  0.0312137
# Accuracy 0.684
# Epoch 27, CIFAR-10 Batch 4:  Loss:  0.0133513
# Accuracy 0.7002
# Epoch 27, CIFAR-10 Batch 5:  Loss:  0.0163172
# Accuracy 0.6838
# Epoch 28, CIFAR-10 Batch 1:  Loss:  0.0235294
# Accuracy 0.6666
# Epoch 28, CIFAR-10 Batch 2:  Loss:  0.0183681
# Accuracy 0.6856
# Epoch 28, CIFAR-10 Batch 3:  Loss:  0.0251206
# Accuracy 0.685
# Epoch 28, CIFAR-10 Batch 4:  Loss:  0.00900514
# Accuracy 0.7024
# Epoch 28, CIFAR-10 Batch 5:  Loss:  0.00704351
# Accuracy 0.6992
# Epoch 29, CIFAR-10 Batch 1:  Loss:  0.0208293
# Accuracy 0.6608
# Epoch 29, CIFAR-10 Batch 2:  Loss:  0.00878832
# Accuracy 0.6932
# Epoch 29, CIFAR-10 Batch 3:  Loss:  0.0161653
# Accuracy 0.6934
# Epoch 29, CIFAR-10 Batch 4:  Loss:  0.00750642
# Accuracy 0.7004
# Epoch 29, CIFAR-10 Batch 5:  Loss:  0.0146731
# Accuracy 0.6874
# Epoch 30, CIFAR-10 Batch 1:  Loss:  0.00937071
# Accuracy 0.6854
# Epoch 30, CIFAR-10 Batch 2:  Loss:  0.019066
# Accuracy 0.6722
# Epoch 30, CIFAR-10 Batch 3:  Loss:  0.0145798
# Accuracy 0.6906
# Epoch 30, CIFAR-10 Batch 4:  Loss:  0.0055687
# Accuracy 0.7
# Epoch 30, CIFAR-10 Batch 5:  Loss:  0.0110315
# Accuracy 0.6818
# Epoch 31, CIFAR-10 Batch 1:  Loss:  0.01079
# Accuracy 0.6902
# Epoch 31, CIFAR-10 Batch 2:  Loss:  0.0100923
# Accuracy 0.6782
# Epoch 31, CIFAR-10 Batch 3:  Loss:  0.0102806
# Accuracy 0.684
# Epoch 31, CIFAR-10 Batch 4:  Loss:  0.00694783
# Accuracy 0.6854
# Epoch 31, CIFAR-10 Batch 5:  Loss:  0.00606413
# Accuracy 0.6884
# Epoch 32, CIFAR-10 Batch 1:  Loss:  0.00922702
# Accuracy 0.6824
# Epoch 32, CIFAR-10 Batch 2:  Loss:  0.018283
# Accuracy 0.6558
# Epoch 32, CIFAR-10 Batch 3:  Loss:  0.0135933
# Accuracy 0.6844
# Epoch 32, CIFAR-10 Batch 4:  Loss:  0.0112909
# Accuracy 0.6862
# Epoch 32, CIFAR-10 Batch 5:  Loss:  0.00580562
# Accuracy 0.6802
# Epoch 33, CIFAR-10 Batch 1:  Loss:  0.0162104
# Accuracy 0.6848
# Epoch 33, CIFAR-10 Batch 2:  Loss:  0.0206507
# Accuracy 0.6748
# Epoch 33, CIFAR-10 Batch 3:  Loss:  0.012186
# Accuracy 0.683
# Epoch 33, CIFAR-10 Batch 4:  Loss:  0.00644694
# Accuracy 0.6912
# Epoch 33, CIFAR-10 Batch 5:  Loss:  0.00442456
# Accuracy 0.6796
# Epoch 34, CIFAR-10 Batch 1:  Loss:  0.0119614
# Accuracy 0.6738
# Epoch 34, CIFAR-10 Batch 2:  Loss:  0.00618461
# Accuracy 0.6856
# Epoch 34, CIFAR-10 Batch 3:  Loss:  0.00750806
# Accuracy 0.6892
# Epoch 34, CIFAR-10 Batch 4:  Loss:  0.0070308
# Accuracy 0.6784
# Epoch 34, CIFAR-10 Batch 5:  Loss:  0.00233343
# Accuracy 0.6864
# Epoch 35, CIFAR-10 Batch 1:  Loss:  0.0153328
# Accuracy 0.6848
# Epoch 35, CIFAR-10 Batch 2:  Loss:  0.00447204
# Accuracy 0.679
# Epoch 35, CIFAR-10 Batch 3:  Loss:  0.00278663
# Accuracy 0.6924
# Epoch 35, CIFAR-10 Batch 4:  Loss:  0.00583305
# Accuracy 0.6858
# Epoch 35, CIFAR-10 Batch 5:  Loss:  0.0024668
# Accuracy 0.6796
# Epoch 36, CIFAR-10 Batch 1:  Loss:  0.0110803
# Accuracy 0.6828
# Epoch 36, CIFAR-10 Batch 2:  Loss:  0.00469353
# Accuracy 0.676
# Epoch 36, CIFAR-10 Batch 3:  Loss:  0.00144097
# Accuracy 0.6872
# Epoch 36, CIFAR-10 Batch 4:  Loss:  0.0168961
# Accuracy 0.6826
# Epoch 36, CIFAR-10 Batch 5:  Loss:  0.00204684
# Accuracy 0.6798
# Epoch 37, CIFAR-10 Batch 1:  Loss:  0.0057202
# Accuracy 0.677
# Epoch 37, CIFAR-10 Batch 2:  Loss:  0.00253071
# Accuracy 0.6814
# Epoch 37, CIFAR-10 Batch 3:  Loss:  0.00206598
# Accuracy 0.6932
# Epoch 37, CIFAR-10 Batch 4:  Loss:  0.00355607
# Accuracy 0.683
# Epoch 37, CIFAR-10 Batch 5:  Loss:  0.00293372
# Accuracy 0.6818
# Epoch 38, CIFAR-10 Batch 1:  Loss:  0.00883061
# Accuracy 0.6704
# Epoch 38, CIFAR-10 Batch 2:  Loss:  0.00379367
# Accuracy 0.667
# Epoch 38, CIFAR-10 Batch 3:  Loss:  0.00194338
# Accuracy 0.6918
# Epoch 38, CIFAR-10 Batch 4:  Loss:  0.00321659
# Accuracy 0.6806
# Epoch 38, CIFAR-10 Batch 5:  Loss:  0.000674942
# Accuracy 0.6898
# Epoch 39, CIFAR-10 Batch 1:  Loss:  0.0066348
# Accuracy 0.671
# Epoch 39, CIFAR-10 Batch 2:  Loss:  0.00577541
# Accuracy 0.6596
# Epoch 39, CIFAR-10 Batch 3:  Loss:  0.00534847
# Accuracy 0.69
# Epoch 39, CIFAR-10 Batch 4:  Loss:  0.000985828
# Accuracy 0.6992
# Epoch 39, CIFAR-10 Batch 5:  Loss:  0.00145877
# Accuracy 0.6868
# Epoch 40, CIFAR-10 Batch 1:  Loss:  0.00105162
# Accuracy 0.6882
# Epoch 40, CIFAR-10 Batch 2:  Loss:  0.00408445
# Accuracy 0.678
# Epoch 40, CIFAR-10 Batch 3:  Loss:  0.00109656
# Accuracy 0.6848
# Epoch 40, CIFAR-10 Batch 4:  Loss:  0.00191057
# Accuracy 0.6934
# Epoch 40, CIFAR-10 Batch 5:  Loss:  0.000785244
# Accuracy 0.6896
# Epoch 41, CIFAR-10 Batch 1:  Loss:  0.000906397
# Accuracy 0.6836
# Epoch 41, CIFAR-10 Batch 2:  Loss:  0.0023706
# Accuracy 0.6762
# Epoch 41, CIFAR-10 Batch 3:  Loss:  0.000909129
# Accuracy 0.6796
# Epoch 41, CIFAR-10 Batch 4:  Loss:  0.00312891
# Accuracy 0.683
# Epoch 41, CIFAR-10 Batch 5:  Loss:  0.00247085
# Accuracy 0.6914
# Epoch 42, CIFAR-10 Batch 1:  Loss:  0.00342049
# Accuracy 0.675
# Epoch 42, CIFAR-10 Batch 2:  Loss:  0.00178987
# Accuracy 0.683
# Epoch 42, CIFAR-10 Batch 3:  Loss:  0.00165188
# Accuracy 0.6808
# Epoch 42, CIFAR-10 Batch 4:  Loss:  0.00156274
# Accuracy 0.6886
# Epoch 42, CIFAR-10 Batch 5:  Loss:  0.00183838
# Accuracy 0.6816
# Epoch 43, CIFAR-10 Batch 1:  Loss:  0.000364041
# Accuracy 0.6898
# Epoch 43, CIFAR-10 Batch 2:  Loss:  0.000523343
# Accuracy 0.6826
# Epoch 43, CIFAR-10 Batch 3:  Loss:  0.00120283
# Accuracy 0.6826
# Epoch 43, CIFAR-10 Batch 4:  Loss:  0.00452226
# Accuracy 0.6884
# Epoch 43, CIFAR-10 Batch 5:  Loss:  0.000498277
# Accuracy 0.6856
# Epoch 44, CIFAR-10 Batch 1:  Loss:  0.00113947
# Accuracy 0.6908
# Epoch 44, CIFAR-10 Batch 2:  Loss:  0.000423874
# Accuracy 0.6868
# Epoch 44, CIFAR-10 Batch 3:  Loss:  0.000880544
# Accuracy 0.6806
# Epoch 44, CIFAR-10 Batch 4:  Loss:  0.005112
# Accuracy 0.6948
# Epoch 44, CIFAR-10 Batch 5:  Loss:  0.00616105
# Accuracy 0.6812
# Epoch 45, CIFAR-10 Batch 1:  Loss:  0.000578489
# Accuracy 0.6914
# Epoch 45, CIFAR-10 Batch 2:  Loss:  0.000787632
# Accuracy 0.6842
# Epoch 45, CIFAR-10 Batch 3:  Loss:  0.00113238
# Accuracy 0.6876
# Epoch 45, CIFAR-10 Batch 4:  Loss:  0.000150938
# Accuracy 0.692
# Epoch 45, CIFAR-10 Batch 5:  Loss:  0.000478665
# Accuracy 0.6914
# Epoch 46, CIFAR-10 Batch 1:  Loss:  0.00116401
# Accuracy 0.6864
# Epoch 46, CIFAR-10 Batch 2:  Loss:  0.000370169
# Accuracy 0.6922
# Epoch 46, CIFAR-10 Batch 3:  Loss:  0.0001883
# Accuracy 0.6892
# Epoch 46, CIFAR-10 Batch 4:  Loss:  0.00482786
# Accuracy 0.6756
# Epoch 46, CIFAR-10 Batch 5:  Loss:  0.00352685
# Accuracy 0.6814
# Epoch 47, CIFAR-10 Batch 1:  Loss:  0.000183266
# Accuracy 0.6926
# Epoch 47, CIFAR-10 Batch 2:  Loss:  0.000609576
# Accuracy 0.6796
# Epoch 47, CIFAR-10 Batch 3:  Loss:  0.000843732
# Accuracy 0.6936
# Epoch 47, CIFAR-10 Batch 4:  Loss:  0.000200207
# Accuracy 0.6902
# Epoch 47, CIFAR-10 Batch 5:  Loss:  0.000453379
# Accuracy 0.685
# Epoch 48, CIFAR-10 Batch 1:  Loss:  0.00181523
# Accuracy 0.6828
# Epoch 48, CIFAR-10 Batch 2:  Loss:  0.000387382
# Accuracy 0.6806
# Epoch 48, CIFAR-10 Batch 3:  Loss:  0.00127621
# Accuracy 0.6894
# Epoch 48, CIFAR-10 Batch 4:  Loss:  0.000552532
# Accuracy 0.6804
# Epoch 48, CIFAR-10 Batch 5:  Loss:  0.00136575
# Accuracy 0.6916
# Epoch 49, CIFAR-10 Batch 1:  Loss:  0.000394574
# Accuracy 0.6878
# Epoch 49, CIFAR-10 Batch 2:  Loss:  0.00101668
# Accuracy 0.6764
# Epoch 49, CIFAR-10 Batch 3:  Loss:  0.000171847
# Accuracy 0.6884
# Epoch 49, CIFAR-10 Batch 4:  Loss:  0.000418366
# Accuracy 0.6784
# Epoch 49, CIFAR-10 Batch 5:  Loss:  0.000670712
# Accuracy 0.682
# Epoch 50, CIFAR-10 Batch 1:  Loss:  0.00080096
# Accuracy 0.6828
# Epoch 50, CIFAR-10 Batch 2:  Loss:  0.000778774
# Accuracy 0.6796
# Epoch 50, CIFAR-10 Batch 3:  Loss:  0.000894437
# Accuracy 0.6806
# Epoch 50, CIFAR-10 Batch 4:  Loss:  0.000277082
# Accuracy 0.686
# Epoch 50, CIFAR-10 Batch 5:  Loss:  0.000772332
# Accuracy 0.6882
# Epoch 51, CIFAR-10 Batch 1:  Loss:  0.0173726
# Accuracy 0.6784
# Epoch 51, CIFAR-10 Batch 2:  Loss:  0.000674764
# Accuracy 0.6924
# Epoch 51, CIFAR-10 Batch 3:  Loss:  0.000216188
# Accuracy 0.6912
# Epoch 51, CIFAR-10 Batch 4:  Loss:  0.000149561
# Accuracy 0.6912
# Epoch 51, CIFAR-10 Batch 5:  Loss:  0.000955329
# Accuracy 0.688
# Epoch 52, CIFAR-10 Batch 1:  Loss:  0.00202965
# Accuracy 0.679
# Epoch 52, CIFAR-10 Batch 2:  Loss:  0.000300871
# Accuracy 0.6934
# Epoch 52, CIFAR-10 Batch 3:  Loss:  5.17392e-05
# Accuracy 0.6814
# Epoch 52, CIFAR-10 Batch 4:  Loss:  0.000369656
# Accuracy 0.6932
# Epoch 52, CIFAR-10 Batch 5:  Loss:  0.000242361
# Accuracy 0.6834
# Epoch 53, CIFAR-10 Batch 1:  Loss:  0.000410166
# Accuracy 0.6888
# Epoch 53, CIFAR-10 Batch 2:  Loss:  0.000283798
# Accuracy 0.6842
# Epoch 53, CIFAR-10 Batch 3:  Loss:  8.76464e-05
# Accuracy 0.6858
# Epoch 53, CIFAR-10 Batch 4:  Loss:  0.00129199
# Accuracy 0.69
# Epoch 53, CIFAR-10 Batch 5:  Loss:  0.00101781
# Accuracy 0.6792
# Epoch 54, CIFAR-10 Batch 1:  Loss:  0.000292176
# Accuracy 0.6776
# Epoch 54, CIFAR-10 Batch 2:  Loss:  0.000198934
# Accuracy 0.6948
# Epoch 54, CIFAR-10 Batch 3:  Loss:  3.84168e-05
# Accuracy 0.69
# Epoch 54, CIFAR-10 Batch 4:  Loss:  0.000605556
# Accuracy 0.6914
# Epoch 54, CIFAR-10 Batch 5:  Loss:  0.000565215
# Accuracy 0.6908
# Epoch 55, CIFAR-10 Batch 1:  Loss:  0.000554828
# Accuracy 0.6702
# Epoch 55, CIFAR-10 Batch 2:  Loss:  0.00113736
# Accuracy 0.685
# Epoch 55, CIFAR-10 Batch 3:  Loss:  6.61134e-05
# Accuracy 0.6808
# Epoch 55, CIFAR-10 Batch 4:  Loss:  0.00021452
# Accuracy 0.6852
# Epoch 55, CIFAR-10 Batch 5:  Loss:  0.000111249
# Accuracy 0.6812
# Epoch 56, CIFAR-10 Batch 1:  Loss:  0.000426138
# Accuracy 0.6748
# Epoch 56, CIFAR-10 Batch 2:  Loss:  9.08703e-05
# Accuracy 0.6836
# Epoch 56, CIFAR-10 Batch 3:  Loss:  2.20456e-05
# Accuracy 0.6838
# Epoch 56, CIFAR-10 Batch 4:  Loss:  0.000263561
# Accuracy 0.6892
# Epoch 56, CIFAR-10 Batch 5:  Loss:  0.00715132
# Accuracy 0.6786
# Epoch 57, CIFAR-10 Batch 1:  Loss:  0.000856609
# Accuracy 0.6896
# Epoch 57, CIFAR-10 Batch 2:  Loss:  0.000406284
# Accuracy 0.688
# Epoch 57, CIFAR-10 Batch 3:  Loss:  0.000243341
# Accuracy 0.6834
# Epoch 57, CIFAR-10 Batch 4:  Loss:  0.000193293
# Accuracy 0.6904
# Epoch 57, CIFAR-10 Batch 5:  Loss:  8.41998e-05
# Accuracy 0.676
# Epoch 58, CIFAR-10 Batch 1:  Loss:  0.000404095
# Accuracy 0.6814
# Epoch 58, CIFAR-10 Batch 2:  Loss:  0.00062598
# Accuracy 0.6828
# Epoch 58, CIFAR-10 Batch 3:  Loss:  5.22972e-05
# Accuracy 0.686
# Epoch 58, CIFAR-10 Batch 4:  Loss:  0.0058193
# Accuracy 0.686
# Epoch 58, CIFAR-10 Batch 5:  Loss:  7.24717e-05
# Accuracy 0.6824
# Epoch 59, CIFAR-10 Batch 1:  Loss:  0.000101234
# Accuracy 0.6866
# Epoch 59, CIFAR-10 Batch 2:  Loss:  5.91076e-05
# Accuracy 0.6788
# Epoch 59, CIFAR-10 Batch 3:  Loss:  2.45925e-05
# Accuracy 0.6854
# Epoch 59, CIFAR-10 Batch 4:  Loss:  0.000158867
# Accuracy 0.6904
# Epoch 59, CIFAR-10 Batch 5:  Loss:  0.000879761
# Accuracy 0.6722
# Epoch 60, CIFAR-10 Batch 1:  Loss:  0.000172744
# Accuracy 0.6862
# Epoch 60, CIFAR-10 Batch 2:  Loss:  6.27767e-05
# Accuracy 0.687
# Epoch 60, CIFAR-10 Batch 3:  Loss:  0.000136132
# Accuracy 0.6848
# Epoch 60, CIFAR-10 Batch 4:  Loss:  0.000139978
# Accuracy 0.6862
# Epoch 60, CIFAR-10 Batch 5:  Loss:  0.000196955
# Accuracy 0.6798
# Epoch 61, CIFAR-10 Batch 1:  Loss:  2.47218e-05
# Accuracy 0.6838
# Epoch 61, CIFAR-10 Batch 2:  Loss:  6.52792e-05
# Accuracy 0.6746
# Epoch 61, CIFAR-10 Batch 3:  Loss:  0.000150443
# Accuracy 0.683
# Epoch 61, CIFAR-10 Batch 4:  Loss:  7.90604e-05
# Accuracy 0.6824
# Epoch 61, CIFAR-10 Batch 5:  Loss:  0.000253145
# Accuracy 0.6786
# Epoch 62, CIFAR-10 Batch 1:  Loss:  0.000231202
# Accuracy 0.6968
# Epoch 62, CIFAR-10 Batch 2:  Loss:  8.54671e-05
# Accuracy 0.6834
# Epoch 62, CIFAR-10 Batch 3:  Loss:  0.00022358
# Accuracy 0.6894
# Epoch 62, CIFAR-10 Batch 4:  Loss:  8.6466e-05
# Accuracy 0.688
# Epoch 62, CIFAR-10 Batch 5:  Loss:  3.30344e-05
# Accuracy 0.6802
# Epoch 63, CIFAR-10 Batch 1:  Loss:  0.000161129
# Accuracy 0.6836
# Epoch 63, CIFAR-10 Batch 2:  Loss:  0.000273227
# Accuracy 0.6792
# Epoch 63, CIFAR-10 Batch 3:  Loss:  0.000729581
# Accuracy 0.691
# Epoch 63, CIFAR-10 Batch 4:  Loss:  0.00112898
# Accuracy 0.685
# Epoch 63, CIFAR-10 Batch 5:  Loss:  0.000126778
# Accuracy 0.6816
# Epoch 64, CIFAR-10 Batch 1:  Loss:  0.000894763
# Accuracy 0.6836
# Epoch 64, CIFAR-10 Batch 2:  Loss:  0.000445667
# Accuracy 0.677
# Epoch 64, CIFAR-10 Batch 3:  Loss:  1.38088e-05
# Accuracy 0.6884
# Epoch 64, CIFAR-10 Batch 4:  Loss:  0.000126728
# Accuracy 0.6866
# Epoch 64, CIFAR-10 Batch 5:  Loss:  3.37501e-05
# Accuracy 0.6862
# Epoch 65, CIFAR-10 Batch 1:  Loss:  4.80845e-05
# Accuracy 0.6872
# Epoch 65, CIFAR-10 Batch 2:  Loss:  0.00214573
# Accuracy 0.6804
# Epoch 65, CIFAR-10 Batch 3:  Loss:  0.00103049
# Accuracy 0.6848
# Epoch 65, CIFAR-10 Batch 4:  Loss:  0.000136953
# Accuracy 0.698
# Epoch 65, CIFAR-10 Batch 5:  Loss:  4.10613e-05
# Accuracy 0.6888
# Epoch 66, CIFAR-10 Batch 1:  Loss:  0.000732842
# Accuracy 0.6828
# Epoch 66, CIFAR-10 Batch 2:  Loss:  6.29336e-05
# Accuracy 0.6738
# Epoch 66, CIFAR-10 Batch 3:  Loss:  0.000113287
# Accuracy 0.6858
# Epoch 66, CIFAR-10 Batch 4:  Loss:  0.00841651
# Accuracy 0.6884
# Epoch 66, CIFAR-10 Batch 5:  Loss:  0.000285461
# Accuracy 0.685
# Epoch 67, CIFAR-10 Batch 1:  Loss:  0.0001078
# Accuracy 0.6878
# Epoch 67, CIFAR-10 Batch 2:  Loss:  9.87308e-05
# Accuracy 0.6734
# Epoch 67, CIFAR-10 Batch 3:  Loss:  2.07073e-05
# Accuracy 0.691
# Epoch 67, CIFAR-10 Batch 4:  Loss:  0.000510415
# Accuracy 0.6842
# Epoch 67, CIFAR-10 Batch 5:  Loss:  1.04774e-05
# Accuracy 0.679
# Epoch 68, CIFAR-10 Batch 1:  Loss:  0.00154918
# Accuracy 0.6938
# Epoch 68, CIFAR-10 Batch 2:  Loss:  5.26518e-05
# Accuracy 0.6716
# Epoch 68, CIFAR-10 Batch 3:  Loss:  9.84323e-06
# Accuracy 0.684
# Epoch 68, CIFAR-10 Batch 4:  Loss:  0.00306353
# Accuracy 0.6886
# Epoch 68, CIFAR-10 Batch 5:  Loss:  8.14308e-05
# Accuracy 0.6878
# Epoch 69, CIFAR-10 Batch 1:  Loss:  0.000338485
# Accuracy 0.6924
# Epoch 69, CIFAR-10 Batch 2:  Loss:  2.3363e-05
# Accuracy 0.6714
# Epoch 69, CIFAR-10 Batch 3:  Loss:  1.03694e-05
# Accuracy 0.6794
# Epoch 69, CIFAR-10 Batch 4:  Loss:  8.40574e-05
# Accuracy 0.6834
# Epoch 69, CIFAR-10 Batch 5:  Loss:  3.22317e-05
# Accuracy 0.6882
# Epoch 70, CIFAR-10 Batch 1:  Loss:  1.94962e-05
# Accuracy 0.6892
# Epoch 70, CIFAR-10 Batch 2:  Loss:  0.000114986
# Accuracy 0.6804
# Epoch 70, CIFAR-10 Batch 3:  Loss:  2.79837e-06
# Accuracy 0.6788
# Epoch 70, CIFAR-10 Batch 4:  Loss:  1.56362e-05
# Accuracy 0.6854
# Epoch 70, CIFAR-10 Batch 5:  Loss:  2.15079e-05
# Accuracy 0.6928
# Epoch 71, CIFAR-10 Batch 1:  Loss:  2.36277e-05
# Accuracy 0.6924
# Epoch 71, CIFAR-10 Batch 2:  Loss:  1.85998e-05
# Accuracy 0.6764
# Epoch 71, CIFAR-10 Batch 3:  Loss:  1.31346e-05
# Accuracy 0.6852
# Epoch 71, CIFAR-10 Batch 4:  Loss:  3.86447e-05
# Accuracy 0.6844
# Epoch 71, CIFAR-10 Batch 5:  Loss:  0.000237004
# Accuracy 0.685
# Epoch 72, CIFAR-10 Batch 1:  Loss:  5.54013e-06
# Accuracy 0.6948
# Epoch 72, CIFAR-10 Batch 2:  Loss:  0.000177127
# Accuracy 0.6736
# Epoch 72, CIFAR-10 Batch 3:  Loss:  1.26827e-05
# Accuracy 0.6878
# Epoch 72, CIFAR-10 Batch 4:  Loss:  4.00536e-06
# Accuracy 0.691
# Epoch 72, CIFAR-10 Batch 5:  Loss:  2.56127e-05
# Accuracy 0.689
# Epoch 73, CIFAR-10 Batch 1:  Loss:  2.59805e-05
# Accuracy 0.6826
# Epoch 73, CIFAR-10 Batch 2:  Loss:  0.000100244
# Accuracy 0.6782
# Epoch 73, CIFAR-10 Batch 3:  Loss:  3.88018e-06
# Accuracy 0.6886
# Epoch 73, CIFAR-10 Batch 4:  Loss:  9.09389e-05
# Accuracy 0.6824
# Epoch 73, CIFAR-10 Batch 5:  Loss:  0.000517537
# Accuracy 0.6902
# Epoch 74, CIFAR-10 Batch 1:  Loss:  1.23847e-05
# Accuracy 0.689
# Epoch 74, CIFAR-10 Batch 2:  Loss:  0.000513842
# Accuracy 0.6728
# Epoch 74, CIFAR-10 Batch 3:  Loss:  1.05938e-05
# Accuracy 0.684
# Epoch 74, CIFAR-10 Batch 4:  Loss:  1.62143e-05
# Accuracy 0.6844
# Epoch 74, CIFAR-10 Batch 5:  Loss:  3.84779e-05
# Accuracy 0.6836
# Epoch 75, CIFAR-10 Batch 1:  Loss:  5.44769e-06
# Accuracy 0.689
# Epoch 75, CIFAR-10 Batch 2:  Loss:  3.00553e-05
# Accuracy 0.6772
# Epoch 75, CIFAR-10 Batch 3:  Loss:  1.85074e-05
# Accuracy 0.674
# Epoch 75, CIFAR-10 Batch 4:  Loss:  0.00116366
# Accuracy 0.6824
# Epoch 75, CIFAR-10 Batch 5:  Loss:  1.55786e-05
# Accuracy 0.681
# Epoch 76, CIFAR-10 Batch 1:  Loss:  1.36606e-05
# Accuracy 0.6826
# Epoch 76, CIFAR-10 Batch 2:  Loss:  0.000955468
# Accuracy 0.6758
# Epoch 76, CIFAR-10 Batch 3:  Loss:  0.000231725
# Accuracy 0.6872
# Epoch 76, CIFAR-10 Batch 4:  Loss:  0.000181387
# Accuracy 0.6858
# Epoch 76, CIFAR-10 Batch 5:  Loss:  0.000373649
# Accuracy 0.693
# Epoch 77, CIFAR-10 Batch 1:  Loss:  8.27706e-05
# Accuracy 0.6814
# Epoch 77, CIFAR-10 Batch 2:  Loss:  4.55656e-05
# Accuracy 0.6746
# Epoch 77, CIFAR-10 Batch 3:  Loss:  2.3186e-06
# Accuracy 0.6854
# Epoch 77, CIFAR-10 Batch 4:  Loss:  6.83322e-06
# Accuracy 0.6848
# Epoch 77, CIFAR-10 Batch 5:  Loss:  1.67196e-05
# Accuracy 0.6936
# Epoch 78, CIFAR-10 Batch 1:  Loss:  0.000163564
# Accuracy 0.6688
# Epoch 78, CIFAR-10 Batch 2:  Loss:  0.000172452
# Accuracy 0.68
# Epoch 78, CIFAR-10 Batch 3:  Loss:  0.000249243
# Accuracy 0.678
# Epoch 78, CIFAR-10 Batch 4:  Loss:  0.000124124
# Accuracy 0.678
# Epoch 78, CIFAR-10 Batch 5:  Loss:  6.44536e-05
# Accuracy 0.6874
# Epoch 79, CIFAR-10 Batch 1:  Loss:  3.80276e-05
# Accuracy 0.6818
# Epoch 79, CIFAR-10 Batch 2:  Loss:  0.000575354
# Accuracy 0.683
# Epoch 79, CIFAR-10 Batch 3:  Loss:  7.25365e-06
# Accuracy 0.6816
# Epoch 79, CIFAR-10 Batch 4:  Loss:  0.000802708
# Accuracy 0.6774
# Epoch 79, CIFAR-10 Batch 5:  Loss:  0.00228499
# Accuracy 0.6866
# Epoch 80, CIFAR-10 Batch 1:  Loss:  1.06624e-05
# Accuracy 0.683
# Epoch 80, CIFAR-10 Batch 2:  Loss:  6.90218e-05
# Accuracy 0.677
# Epoch 80, CIFAR-10 Batch 3:  Loss:  1.66429e-05
# Accuracy 0.6836
# Epoch 80, CIFAR-10 Batch 4:  Loss:  5.31872e-05
# Accuracy 0.6748
# Epoch 80, CIFAR-10 Batch 5:  Loss:  1.80406e-05
# Accuracy 0.6842
# Epoch 81, CIFAR-10 Batch 1:  Loss:  3.18917e-05
# Accuracy 0.6754
# Epoch 81, CIFAR-10 Batch 2:  Loss:  0.000317419
# Accuracy 0.68
# Epoch 81, CIFAR-10 Batch 3:  Loss:  6.30889e-06
# Accuracy 0.6894
# Epoch 81, CIFAR-10 Batch 4:  Loss:  4.5227e-05
# Accuracy 0.675
# Epoch 81, CIFAR-10 Batch 5:  Loss:  0.000177308
# Accuracy 0.6912
# Epoch 82, CIFAR-10 Batch 1:  Loss:  0.000595982
# Accuracy 0.6916
# Epoch 82, CIFAR-10 Batch 2:  Loss:  0.000417588
# Accuracy 0.6854
# Epoch 82, CIFAR-10 Batch 3:  Loss:  0.000282958
# Accuracy 0.6886
# Epoch 82, CIFAR-10 Batch 4:  Loss:  5.54074e-05
# Accuracy 0.6818
# Epoch 82, CIFAR-10 Batch 5:  Loss:  0.00047368
# Accuracy 0.6868
# Epoch 83, CIFAR-10 Batch 1:  Loss:  6.71575e-05
# Accuracy 0.6858
# Epoch 83, CIFAR-10 Batch 2:  Loss:  5.19965e-05
# Accuracy 0.6768
# Epoch 83, CIFAR-10 Batch 3:  Loss:  5.06597e-06
# Accuracy 0.6826
# Epoch 83, CIFAR-10 Batch 4:  Loss:  5.2626e-05
# Accuracy 0.6818
# Epoch 83, CIFAR-10 Batch 5:  Loss:  8.5075e-06
# Accuracy 0.6836
# Epoch 84, CIFAR-10 Batch 1:  Loss:  0.0007178
# Accuracy 0.6904
# Epoch 84, CIFAR-10 Batch 2:  Loss:  9.63499e-05
# Accuracy 0.6786
# Epoch 84, CIFAR-10 Batch 3:  Loss:  2.9359e-05
# Accuracy 0.676
# Epoch 84, CIFAR-10 Batch 4:  Loss:  0.000129837
# Accuracy 0.683
# Epoch 84, CIFAR-10 Batch 5:  Loss:  3.99895e-05
# Accuracy 0.6856
# Epoch 85, CIFAR-10 Batch 1:  Loss:  2.83414e-05
# Accuracy 0.6892
# Epoch 85, CIFAR-10 Batch 2:  Loss:  5.23408e-05
# Accuracy 0.6758
# Epoch 85, CIFAR-10 Batch 3:  Loss:  1.6838e-06
# Accuracy 0.6852
# Epoch 85, CIFAR-10 Batch 4:  Loss:  0.000196584
# Accuracy 0.6856
# Epoch 85, CIFAR-10 Batch 5:  Loss:  1.26282e-05
# Accuracy 0.6814
# Epoch 86, CIFAR-10 Batch 1:  Loss:  0.000795511
# Accuracy 0.6848
# Epoch 86, CIFAR-10 Batch 2:  Loss:  0.000348416
# Accuracy 0.6808
# Epoch 86, CIFAR-10 Batch 3:  Loss:  5.15541e-06
# Accuracy 0.6872
# Epoch 86, CIFAR-10 Batch 4:  Loss:  6.24054e-05
# Accuracy 0.6728
# Epoch 86, CIFAR-10 Batch 5:  Loss:  0.000162875
# Accuracy 0.6772
# Epoch 87, CIFAR-10 Batch 1:  Loss:  3.53004e-05
# Accuracy 0.6932
# Epoch 87, CIFAR-10 Batch 2:  Loss:  2.55467e-05
# Accuracy 0.6792
# Epoch 87, CIFAR-10 Batch 3:  Loss:  0.000911393
# Accuracy 0.6832
# Epoch 87, CIFAR-10 Batch 4:  Loss:  2.38246e-05
# Accuracy 0.6776
# Epoch 87, CIFAR-10 Batch 5:  Loss:  7.95066e-06
# Accuracy 0.682
# Epoch 88, CIFAR-10 Batch 1:  Loss:  0.000105683
# Accuracy 0.6806
# Epoch 88, CIFAR-10 Batch 2:  Loss:  6.12796e-05
# Accuracy 0.683
# Epoch 88, CIFAR-10 Batch 3:  Loss:  4.08413e-05
# Accuracy 0.6812
# Epoch 88, CIFAR-10 Batch 4:  Loss:  1.12354e-06
# Accuracy 0.692
# Epoch 88, CIFAR-10 Batch 5:  Loss:  6.84164e-05
# Accuracy 0.6832
# Epoch 89, CIFAR-10 Batch 1:  Loss:  2.75666e-06
# Accuracy 0.6874
# Epoch 89, CIFAR-10 Batch 2:  Loss:  4.84963e-05
# Accuracy 0.6858
# Epoch 89, CIFAR-10 Batch 3:  Loss:  2.59275e-06
# Accuracy 0.693
# Epoch 89, CIFAR-10 Batch 4:  Loss:  0.000587513
# Accuracy 0.6842
# Epoch 89, CIFAR-10 Batch 5:  Loss:  1.49905e-06
# Accuracy 0.683
# Epoch 90, CIFAR-10 Batch 1:  Loss:  7.84331e-06
# Accuracy 0.689
# Epoch 90, CIFAR-10 Batch 2:  Loss:  7.2296e-06
# Accuracy 0.6834
# Epoch 90, CIFAR-10 Batch 3:  Loss:  5.1169e-06
# Accuracy 0.6838
# Epoch 90, CIFAR-10 Batch 4:  Loss:  2.07279e-05
# Accuracy 0.6838
# Epoch 90, CIFAR-10 Batch 5:  Loss:  2.09296e-05
# Accuracy 0.6898
# Epoch 91, CIFAR-10 Batch 1:  Loss:  1.18437e-05
# Accuracy 0.6954
# Epoch 91, CIFAR-10 Batch 2:  Loss:  4.68182e-06
# Accuracy 0.6822
# Epoch 91, CIFAR-10 Batch 3:  Loss:  1.70865e-05
# Accuracy 0.6856
# Epoch 91, CIFAR-10 Batch 4:  Loss:  1.66038e-05
# Accuracy 0.6942
# Epoch 91, CIFAR-10 Batch 5:  Loss:  4.26172e-07
# Accuracy 0.682
# Epoch 92, CIFAR-10 Batch 1:  Loss:  2.71337e-05
# Accuracy 0.692
# Epoch 92, CIFAR-10 Batch 2:  Loss:  1.90316e-05
# Accuracy 0.6848
# Epoch 92, CIFAR-10 Batch 3:  Loss:  1.61229e-06
# Accuracy 0.6832
# Epoch 92, CIFAR-10 Batch 4:  Loss:  1.01799e-05
# Accuracy 0.6886
# Epoch 92, CIFAR-10 Batch 5:  Loss:  3.15897e-06
# Accuracy 0.6856
# Epoch 93, CIFAR-10 Batch 1:  Loss:  3.37055e-06
# Accuracy 0.6946
# Epoch 93, CIFAR-10 Batch 2:  Loss:  1.0003e-05
# Accuracy 0.6852
# Epoch 93, CIFAR-10 Batch 3:  Loss:  1.46624e-05
# Accuracy 0.6894
# Epoch 93, CIFAR-10 Batch 4:  Loss:  1.58076e-05
# Accuracy 0.6898
# Epoch 93, CIFAR-10 Batch 5:  Loss:  7.67298e-06
# Accuracy 0.6854
# Epoch 94, CIFAR-10 Batch 1:  Loss:  4.35024e-05
# Accuracy 0.6918
# Epoch 94, CIFAR-10 Batch 2:  Loss:  7.92796e-05
# Accuracy 0.6832
# Epoch 94, CIFAR-10 Batch 3:  Loss:  3.27825e-07
# Accuracy 0.688
# Epoch 94, CIFAR-10 Batch 4:  Loss:  0.00010306
# Accuracy 0.6766
# Epoch 94, CIFAR-10 Batch 5:  Loss:  4.6618e-05
# Accuracy 0.6788
# Epoch 95, CIFAR-10 Batch 1:  Loss:  1.41201e-05
# Accuracy 0.6792
# Epoch 95, CIFAR-10 Batch 2:  Loss:  5.83713e-05
# Accuracy 0.6738
# Epoch 95, CIFAR-10 Batch 3:  Loss:  3.43615e-06
# Accuracy 0.6782
# Epoch 95, CIFAR-10 Batch 4:  Loss:  0.00159838
# Accuracy 0.6836
# Epoch 95, CIFAR-10 Batch 5:  Loss:  0.000366533
# Accuracy 0.6892
# Epoch 96, CIFAR-10 Batch 1:  Loss:  2.0325e-06
# Accuracy 0.6878
# Epoch 96, CIFAR-10 Batch 2:  Loss:  0.00017773
# Accuracy 0.6764
# Epoch 96, CIFAR-10 Batch 3:  Loss:  5.6056e-06
# Accuracy 0.678
# Epoch 96, CIFAR-10 Batch 4:  Loss:  0.000138457
# Accuracy 0.688
# Epoch 96, CIFAR-10 Batch 5:  Loss:  2.37522e-06
# Accuracy 0.6882
# Epoch 97, CIFAR-10 Batch 1:  Loss:  6.8065e-06
# Accuracy 0.6952
# Epoch 97, CIFAR-10 Batch 2:  Loss:  1.40664e-06
# Accuracy 0.6846
# Epoch 97, CIFAR-10 Batch 3:  Loss:  5.6649e-06
# Accuracy 0.686
# Epoch 97, CIFAR-10 Batch 4:  Loss:  3.41229e-06
# Accuracy 0.6868
# Epoch 97, CIFAR-10 Batch 5:  Loss:  4.51787e-06
# Accuracy 0.6898
# Epoch 98, CIFAR-10 Batch 1:  Loss:  0.000111893
# Accuracy 0.688
# Epoch 98, CIFAR-10 Batch 2:  Loss:  2.72287e-05
# Accuracy 0.683
# Epoch 98, CIFAR-10 Batch 3:  Loss:  1.19975e-05
# Accuracy 0.6836
# Epoch 98, CIFAR-10 Batch 4:  Loss:  0.000548137
# Accuracy 0.6776
# Epoch 98, CIFAR-10 Batch 5:  Loss:  8.75554e-06
# Accuracy 0.6848
# Epoch 99, CIFAR-10 Batch 1:  Loss:  4.97658e-06
# Accuracy 0.6838
# Epoch 99, CIFAR-10 Batch 2:  Loss:  9.65586e-07
# Accuracy 0.6862
# Epoch 99, CIFAR-10 Batch 3:  Loss:  1.61531e-05
# Accuracy 0.6938
# Epoch 99, CIFAR-10 Batch 4:  Loss:  3.61492e-05
# Accuracy 0.6986
# Epoch 99, CIFAR-10 Batch 5:  Loss:  7.69765e-05
# Accuracy 0.6858
# Epoch 100, CIFAR-10 Batch 1:  Loss:  0.000279891
# Accuracy 0.6902
# Epoch 100, CIFAR-10 Batch 2:  Loss:  1.96396e-06
# Accuracy 0.6834
# Epoch 100, CIFAR-10 Batch 3:  Loss:  1.86558e-06
# Accuracy 0.685
# Epoch 100, CIFAR-10 Batch 4:  Loss:  1.34986e-05
# Accuracy 0.6798
# Epoch 100, CIFAR-10 Batch 5:  Loss:  2.42885e-06
# Accuracy 0.687

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.67978515625

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
